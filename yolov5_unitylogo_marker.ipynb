# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils

display = utils.notebook_init()  # checks

from IPython. display import Image, clear_output # to display images

# %%
# !pip install roboflow
import os
from roboflow import Roboflow

rf = Roboflow(api_key="S6yIqitYPtQh1aWo1oq7", model_format="yolov5", notebook="ultralytics")

os.environ["DATASET_DIRECTORY"] = "/content/datasets"

project = rf.workspace("unitylogo1").project("unity-logo-1")
version = project.version(1)
dataset = version.download("yolov5")

# %%
# !python yolov5/train.py --img 640 --batch 16 --epochs 20 --data /content/datasets/Unity-Logo-1-1/data.yaml --weights yolov5s.pt

# %%
import matplotlib.pyplot as plt

# Redefining the data with the new results
epochs = list(range(1, 21))
mAP50_new = [
    0.416, 0.355, 0.452, 0.853, 0.946, 0.913, 0.941, 0.978, 0.963,
    0.982, 0.977, 0.983, 0.983, 0.987, 0.986, 0.987, 0.988, 0.989,
    0.989, 0.989
]
mAP50_95_new = [
    0.107, 0.156, 0.245, 0.354, 0.365, 0.605, 0.599, 0.6, 0.679,
    0.597, 0.785, 0.686, 0.801, 0.814, 0.832, 0.844, 0.864, 0.877,
    0.88, 0.899
]
precision_new = [
    0.852, 0.812, 0.839, 0.662, 0.843, 0.83, 0.846, 0.953, 0.931,
    0.958, 0.955, 0.958, 0.959, 0.959, 0.959, 0.959, 0.959, 0.959,
    0.962, 0.959
]
recall_new = [
    0.404, 0.447, 0.447, 0.826, 0.895, 0.885, 0.947, 1, 0.997,
    1, 0.995, 1, 1, 1, 1, 1, 1, 1, 0.998, 1
]

# Plotting the graph of mAP50, mAP50-95, Precision, and Recall over epochs for the new dataset
plt.figure(figsize=(14, 7))
plt.plot(epochs, mAP50_new, marker='o', linestyle='-', color='blue', label='mAP50')
plt.plot(epochs, mAP50_95_new, marker='v', linestyle='--', color='green', label='mAP50-95')
plt.plot(epochs, precision_new, marker='s', linestyle='-.', color='red', label='Precision')
plt.plot(epochs, recall_new, marker='*', linestyle=':', color='magenta', label='Recall')

plt.title('Model Accuracy Metrics over Epochs (New Data)')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.xticks(epochs)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# !python yolov5/detect.py --weights content/yolov5s.pt --img 416 --conf 0.2 --source /content/datasets/colored-marker-1-1//test/images --save-txt
# Out:
# detect: weights=['content/yolov5s.pt'], source=/content/datasets/colored-marker-1-1//test/images, data=yolov5/data/coco128.yaml, imgsz=[416, 416], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-295-gac6c4383 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to content/yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 137MB/s]
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# image 1/100 /content/datasets/colored-marker-1-1/test/images/1198454303204210_png.rf.65cf7812cf7bec13ee9752fd00ebad4a.jpg: 416x416 3 persons, 7.4ms
# image 2/100 /content/datasets/colored-marker-1-1/test/images/1198454435704210_png.rf.762e92e7e60c7f02c9de18dc8e4a3e69.jpg: 416x416 2 persons, 7.5ms
# image 3/100 /content/datasets/colored-marker-1-1/test/images/1198455903204210_png.rf.d195c67ea0e3663510cc4a4c1a214ac3.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 4/100 /content/datasets/colored-marker-1-1/test/images/1198455968204210_png.rf.9ca943c6f8c13f91db5fa69a3245eb14.jpg: 416x416 2 persons, 1 vase, 8.0ms
# image 5/100 /content/datasets/colored-marker-1-1/test/images/1198456403204210_png.rf.653931cd262f8f50f134debcb00bc7aa.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 6/100 /content/datasets/colored-marker-1-1/test/images/1198456568204210_png.rf.a57b154cff666f8560c050b26ccfead8.jpg: 416x416 2 persons, 7.4ms
# image 7/100 /content/datasets/colored-marker-1-1/test/images/1198456735704210_png.rf.54f83ac4059b620daa20fda7ce39e20e.jpg: 416x416 2 persons, 7.4ms
# image 8/100 /content/datasets/colored-marker-1-1/test/images/1198458303204210_png.rf.45af166a2de69441fd22d11c9382bfd5.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 9/100 /content/datasets/colored-marker-1-1/test/images/1198459635704210_png.rf.70d5eca859e129a2b708ccab8a8bd75f.jpg: 416x416 2 persons, 7.4ms
# image 10/100 /content/datasets/colored-marker-1-1/test/images/1198459668204210_png.rf.a63fc013092a3c12547f9cd67536b22f.jpg: 416x416 2 persons, 7.4ms
# image 11/100 /content/datasets/colored-marker-1-1/test/images/1198462035704210_png.rf.972a5dc7215744dec3a849548517971c.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 12/100 /content/datasets/colored-marker-1-1/test/images/1198462235704210_png.rf.c653169099080e96faed56fd642775ca.jpg: 416x416 2 persons, 2 vases, 7.4ms
# image 13/100 /content/datasets/colored-marker-1-1/test/images/1198462568204210_png.rf.562ab073059bbaab5d9fefada7811b4b.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 14/100 /content/datasets/colored-marker-1-1/test/images/1198462803204210_png.rf.bd85b6957a474f43c44eb19b71277cfc.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 15/100 /content/datasets/colored-marker-1-1/test/images/1198462968204210_png.rf.d42db49465f6aec6700313f164a820db.jpg: 416x416 1 person, 1 vase, 7.4ms
# image 16/100 /content/datasets/colored-marker-1-1/test/images/1198464203204210_png.rf.56889da9f7d70e7131543734c4ddde87.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 17/100 /content/datasets/colored-marker-1-1/test/images/1198464803204210_png.rf.dbd8ace60ba960a8f0d86ba0b378c242.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 18/100 /content/datasets/colored-marker-1-1/test/images/1198464868204210_png.rf.d14c77eaadfda4b823f0345ce5761a21.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 19/100 /content/datasets/colored-marker-1-1/test/images/1198465468204210_png.rf.2245b2981b6944af73b9dd815a2c6011.jpg: 416x416 3 persons, 1 backpack, 7.4ms
# image 20/100 /content/datasets/colored-marker-1-1/test/images/1198465503204210_png.rf.edf0df093c90a96b150cf55385f7fd19.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 21/100 /content/datasets/colored-marker-1-1/test/images/1198466868204210_png.rf.33a12e5af2965abcf3d86cd001ea9c9a.jpg: 416x416 2 persons, 1 vase, 7.8ms
# image 22/100 /content/datasets/colored-marker-1-1/test/images/1198467003204210_png.rf.0bf0408083c2e57e1815718fa8211261.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 23/100 /content/datasets/colored-marker-1-1/test/images/1198467103204210_png.rf.d7b1b792506717b1f1ccee596993b88d.jpg: 416x416 2 persons, 7.4ms
# image 24/100 /content/datasets/colored-marker-1-1/test/images/1198467235704210_png.rf.2fae57ad7d7906fe71c9389f5d91dea9.jpg: 416x416 2 persons, 7.4ms
# image 25/100 /content/datasets/colored-marker-1-1/test/images/1198467403204210_png.rf.8a78e0b4f5850e048e2d1a96801487a8.jpg: 416x416 2 persons, 7.4ms
# image 26/100 /content/datasets/colored-marker-1-1/test/images/1198467768204210_png.rf.8b187dbfff32e2eada8737f861387d19.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 27/100 /content/datasets/colored-marker-1-1/test/images/1198468768204210_png.rf.0285c9db9eefe4519911bf8c11ea52e2.jpg: 416x416 2 persons, 7.4ms
# image 28/100 /content/datasets/colored-marker-1-1/test/images/1198469135704210_png.rf.8a07d9a043c641dfa9d5fba2ad162b43.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 29/100 /content/datasets/colored-marker-1-1/test/images/1198469603204210_png.rf.e026e4f90ed858f6da94674ae1f5c14f.jpg: 416x416 1 person, 1 vase, 7.4ms
# image 30/100 /content/datasets/colored-marker-1-1/test/images/1198469768204210_png.rf.a48aa5c602e128d4c9a948c7744e6d84.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 31/100 /content/datasets/colored-marker-1-1/test/images/1198469835704210_png.rf.8261dfc2a87d39aaa6a3e87214bbab5d.jpg: 416x416 1 person, 1 vase, 10.0ms
# image 32/100 /content/datasets/colored-marker-1-1/test/images/1198470368204210_png.rf.a377dae1a2b8cc2ee97bab4012dba46c.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 33/100 /content/datasets/colored-marker-1-1/test/images/1198470703204210_png.rf.e95558894e40e6681ea53668ead3d64b.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 34/100 /content/datasets/colored-marker-1-1/test/images/1198470903204210_png.rf.53163c27a59b5d280186e4b494e1ec08.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 35/100 /content/datasets/colored-marker-1-1/test/images/1198471135704210_png.rf.ca0dfd0730fbbc222c9aa57f86ed63b6.jpg: 416x416 2 persons, 1 backpack, 1 vase, 7.4ms
# image 36/100 /content/datasets/colored-marker-1-1/test/images/1198471168204210_png.rf.31a9d3ee913349706cf850f42e796e2d.jpg: 416x416 2 persons, 1 backpack, 1 vase, 7.4ms
# image 37/100 /content/datasets/colored-marker-1-1/test/images/1198471268204210_png.rf.15877d7d015ada65656ed1bdf17a6ff0.jpg: 416x416 2 persons, 1 vase, 8.3ms
# image 38/100 /content/datasets/colored-marker-1-1/test/images/1198471335704210_png.rf.365ae8aea8eb1817b6f4571792907038.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 39/100 /content/datasets/colored-marker-1-1/test/images/1198471968204210_png.rf.79795088ea353cb4d479b48c769561eb.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 40/100 /content/datasets/colored-marker-1-1/test/images/1198472003204210_png.rf.e78bb5975c29f0ba7029141cb5b5ce9e.jpg: 416x416 2 persons, 7.4ms
# image 41/100 /content/datasets/colored-marker-1-1/test/images/1198472068204210_png.rf.1febab36bd9e7c1e8dfe21ecd3c0e235.jpg: 416x416 2 persons, 7.4ms
# image 42/100 /content/datasets/colored-marker-1-1/test/images/1198472135704210_png.rf.3fd2017943d545be2fccdbcf86321f2e.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 43/100 /content/datasets/colored-marker-1-1/test/images/1198472535704210_png.rf.66405cc082139065ddc4534e9ebdea99.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 44/100 /content/datasets/colored-marker-1-1/test/images/1198472635704210_png.rf.6f39c1a38f33fee788b0333ce0ac3c26.jpg: 416x416 2 persons, 8.5ms
# image 45/100 /content/datasets/colored-marker-1-1/test/images/1198473003204210_png.rf.d68772b14ec707b96e318e984937190f.jpg: 416x416 2 persons, 7.4ms
# image 46/100 /content/datasets/colored-marker-1-1/test/images/1198473768204210_png.rf.639901c7f42ebf4de98ac96e3b4eaea4.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 47/100 /content/datasets/colored-marker-1-1/test/images/1198474435704210_png.rf.6117acdad3305e8b8abd86b0d5ae5248.jpg: 416x416 3 persons, 7.4ms
# image 48/100 /content/datasets/colored-marker-1-1/test/images/1198474503204210_png.rf.581a4f1d61babf4be05b8651cafd7773.jpg: 416x416 2 persons, 8.2ms
# image 49/100 /content/datasets/colored-marker-1-1/test/images/1198474535704210_png.rf.9c1b45068dd51fe859737f9bdcaf5985.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 50/100 /content/datasets/colored-marker-1-1/test/images/1198474635704210_png.rf.b52a79cf145caf3e66d23d9c9946998b.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 51/100 /content/datasets/colored-marker-1-1/test/images/1198474768204210_png.rf.972f386469ceb520ff5a26c09d41fa53.jpg: 416x416 1 person, 1 vase, 7.4ms
# image 52/100 /content/datasets/colored-marker-1-1/test/images/1198475135704210_png.rf.92d64c5e25c08fdac30bd35836c09492.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 53/100 /content/datasets/colored-marker-1-1/test/images/1198475203204210_png.rf.acf3a1eb6ca5787269ed36d492f5f2bb.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 54/100 /content/datasets/colored-marker-1-1/test/images/1198476535704210_png.rf.e6b28475e217c87802f47a36d08f54cc.jpg: 416x416 2 persons, 1 backpack, 1 vase, 7.4ms
# image 55/100 /content/datasets/colored-marker-1-1/test/images/1198478903204210_png.rf.ada27174329b85b4b8b15b8000282c4f.jpg: 416x416 1 person, 1 vase, 7.6ms
# image 56/100 /content/datasets/colored-marker-1-1/test/images/1198479835704210_png.rf.b4c84a7b9e6056f97126fd3e7a9034f2.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 57/100 /content/datasets/colored-marker-1-1/test/images/1198480368204210_png.rf.5ed747d9d9e10ca03464e24bb654df2d.jpg: 416x416 1 person, 1 bird, 1 vase, 7.4ms
# image 58/100 /content/datasets/colored-marker-1-1/test/images/1198480635704210_png.rf.3e8bb1a0f00420234aabfed24d1d2fed.jpg: 416x416 1 person, 1 bird, 1 vase, 7.4ms
# image 59/100 /content/datasets/colored-marker-1-1/test/images/1198481103204210_png.rf.a8c97357933162eaf3ad7ecf441f45f7.jpg: 416x416 1 person, 1 vase, 7.4ms
# image 60/100 /content/datasets/colored-marker-1-1/test/images/1198481335704210_png.rf.f06421107042fbdc8c40324a096462c8.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 61/100 /content/datasets/colored-marker-1-1/test/images/1198481468204210_png.rf.19bfb206ca3be9958374ffa61f55bbdd.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 62/100 /content/datasets/colored-marker-1-1/test/images/1198481968204210_png.rf.a2a6b8a39d9f0eb7120fe2f6f81ad1ea.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 63/100 /content/datasets/colored-marker-1-1/test/images/1198482335704210_png.rf.b224c366b0e4d029629978fb48759312.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 64/100 /content/datasets/colored-marker-1-1/test/images/1198482568204210_png.rf.bf4edd83ac09c403b4f86cfc931bedb1.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 65/100 /content/datasets/colored-marker-1-1/test/images/1198483503204210_png.rf.289b5d9c5cdb4150a716cff105597e96.jpg: 416x416 1 person, 1 bird, 2 vases, 7.4ms
# image 66/100 /content/datasets/colored-marker-1-1/test/images/1198484635704210_png.rf.f5882ba7e3b9caeb2d3d0d64ac64551b.jpg: 416x416 1 person, 1 vase, 7.4ms
# image 67/100 /content/datasets/colored-marker-1-1/test/images/1198485403204210_png.rf.daebece65cf891ee15fc3d2be740e73a.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 68/100 /content/datasets/colored-marker-1-1/test/images/1198485468204210_png.rf.87764e9ddf387109061448fc670c392d.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 69/100 /content/datasets/colored-marker-1-1/test/images/1198485503204210_png.rf.66377057a3b048b95c120272a5d28c6e.jpg: 416x416 2 persons, 2 vases, 7.4ms
# image 70/100 /content/datasets/colored-marker-1-1/test/images/1198485635704210_png.rf.a581325003eecd862827da958dc030f2.jpg: 416x416 1 person, 1 vase, 7.4ms
# image 71/100 /content/datasets/colored-marker-1-1/test/images/1198486835704210_png.rf.b33f74524e7ef0479d7ffa10c097e90b.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 72/100 /content/datasets/colored-marker-1-1/test/images/1198487768204210_png.rf.674057fa2a093ce6f039f4b7998f8b63.jpg: 416x416 2 persons, 2 vases, 7.4ms
# image 73/100 /content/datasets/colored-marker-1-1/test/images/1198487835704210_png.rf.e22672dcf4a07b19ef756c8a46f1eda1.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 74/100 /content/datasets/colored-marker-1-1/test/images/1198488335704210_png.rf.70c77d6097338c0da9847e91dea1d757.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 75/100 /content/datasets/colored-marker-1-1/test/images/1198488468204210_png.rf.5d8bb25a52f024d9cfa8c53315ed0d07.jpg: 416x416 2 persons, 1 bird, 1 vase, 7.4ms
# image 76/100 /content/datasets/colored-marker-1-1/test/images/1198489168204210_png.rf.fcefd4402f7e3ce5a632cdd55a12b7e7.jpg: 416x416 1 person, 1 tie, 2 vases, 7.4ms
# image 77/100 /content/datasets/colored-marker-1-1/test/images/1198489268204210_png.rf.a5c9bbb32222ebadd874a3f6a7c67912.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 78/100 /content/datasets/colored-marker-1-1/test/images/1198489603204210_png.rf.358d59f8f635bb80d7e29c76916f36c1.jpg: 416x416 1 person, 1 bird, 2 vases, 7.4ms
# image 79/100 /content/datasets/colored-marker-1-1/test/images/1198490335704210_png.rf.c2bc1a41c1ae02cf5d1154d495a359ca.jpg: 416x416 1 person, 1 bird, 1 vase, 7.4ms
# image 80/100 /content/datasets/colored-marker-1-1/test/images/1198490368204210_png.rf.ba606950e85331a2e209287669c06d4d.jpg: 416x416 1 person, 1 vase, 7.9ms
# image 81/100 /content/datasets/colored-marker-1-1/test/images/1198490468204210_png.rf.cb792e54b8564230b03af5b6c5536c14.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 82/100 /content/datasets/colored-marker-1-1/test/images/1198490703204210_png.rf.e32999c0391d4061c7e30f003cf49a92.jpg: 416x416 1 person, 1 bird, 1 vase, 7.4ms
# image 83/100 /content/datasets/colored-marker-1-1/test/images/1198491768204210_png.rf.dd4481bbf8606a6759cd07a2e353d727.jpg: 416x416 2 persons, 2 vases, 7.4ms
# image 84/100 /content/datasets/colored-marker-1-1/test/images/1198492035704210_png.rf.45cb4ad02f4cdcee4b830e4f0143aed6.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 85/100 /content/datasets/colored-marker-1-1/test/images/1198492335704210_png.rf.d756c9cfdc748cd72e6b572666d77a1d.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 86/100 /content/datasets/colored-marker-1-1/test/images/1198492703204210_png.rf.1dd9de81dca23ed91efc59dddd7f9652.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 87/100 /content/datasets/colored-marker-1-1/test/images/1198493335704210_png.rf.d90c78e98e931f042bdd3c9887ee31b1.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 88/100 /content/datasets/colored-marker-1-1/test/images/1198493603204210_png.rf.49840a02a39b5d9eae6c0ddd3aafb956.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 89/100 /content/datasets/colored-marker-1-1/test/images/1198493868204210_png.rf.7be4af6b471dcd67055daa8b01fd18d0.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 90/100 /content/datasets/colored-marker-1-1/test/images/1198494268204210_png.rf.b9f28658a7d11b26bafa2071c986f4f1.jpg: 416x416 2 persons, 1 vase, 7.4ms
# image 91/100 /content/datasets/colored-marker-1-1/test/images/1198496435704210_png.rf.7ce1adf185c7718becebbd3342411038.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 92/100 /content/datasets/colored-marker-1-1/test/images/1198497103204210_png.rf.0a9dc3aeb6458ba03654366ce460891c.jpg: 416x416 1 person, 1 bird, 2 vases, 7.4ms
# image 93/100 /content/datasets/colored-marker-1-1/test/images/1198497168204210_png.rf.b6e64cd32be9e1f37734fa6bf88a3939.jpg: 416x416 1 person, 1 bird, 2 vases, 7.4ms
# image 94/100 /content/datasets/colored-marker-1-1/test/images/1198497403204210_png.rf.b55ff3555936579768d009539c99866f.jpg: 416x416 1 person, 1 bird, 2 vases, 7.4ms
# image 95/100 /content/datasets/colored-marker-1-1/test/images/1198497835704210_png.rf.8bafa68e2bdfb6f337dac07b297fde77.jpg: 416x416 1 person, 1 bird, 2 vases, 7.4ms
# image 96/100 /content/datasets/colored-marker-1-1/test/images/1198498268204210_png.rf.4bd352bf505391b85fb323e20dbdc470.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 97/100 /content/datasets/colored-marker-1-1/test/images/1198498935704210_png.rf.9f80adab958781a68abab88f2887c09a.jpg: 416x416 1 person, 2 vases, 7.5ms
# image 98/100 /content/datasets/colored-marker-1-1/test/images/1198499403204210_png.rf.5ac139b09c2a42a63ec8a4f36feb94da.jpg: 416x416 1 person, 2 vases, 7.4ms
# image 99/100 /content/datasets/colored-marker-1-1/test/images/1198499635704210_png.rf.076c6421aaaf33652025d6d07466f5a8.jpg: 416x416 1 person, 1 bird, 2 vases, 7.4ms
# image 100/100 /content/datasets/colored-marker-1-1/test/images/1198499835704210_png.rf.853b5c04890e3f7c0c4045549ff239c4.jpg: 416x416 1 person, 1 bird, 1 vase, 7.4ms
# Speed: 0.3ms pre-process, 7.5ms inference, 6.0ms NMS per image at shape (1, 3, 416, 416)
# Results saved to yolov5/runs/detect/exp2
# 100 labels saved to yolov5/runs/detect/exp2/labels

# %% [markdown]
# Precision-Recall Curve

# %%
import glob
import os
import matplotlib.pyplot as plt
from sklearn.metrics import precision_recall_curve

# Load ground truth and predicted labels
gt_dir = 'datasets/colored-marker-1-1/test/labels/'
pred_dir = 'yolov5/runs/detect/exp2/labels/'

gt_files = glob.glob(os.path.join(gt_dir, '*.txt'))

# Initialize variables to calculate TP, FP, FN for PR curve and confusion matrix
true_labels = []
score_values = []

def load_labels(file_path):
    with open(file_path, 'r') as f:
        labels = [line.strip().split() for line in f.readlines()]
        return [(int(label[0]), float(label[1]), [float(x) for x in label[2:]]) for label in labels]


def calculate_iou(box1, box2):
    # Convert bounding boxes from (center x, center y, width) to (x1, y1, x2, y2)
    x1_min = box1[0] - box1[2] / 2
    y1_min = box1[1] - box1[2] / 2
    x1_max = box1[0] + box1[2] / 2
    y1_max = box1[1] + box1[2] / 2

    x2_min = box2[0] - box2[2] / 2
    y2_min = box2[1] - box2[2] / 2
    x2_max = box2[0] + box2[2] / 2
    y2_max = box2[1] + box2[2] / 2


    # Calculate the intersection area
    inter_area = max(0, min(x1_max, x2_max) - max(x1_min, x2_min)) * max(0, min(y1_max, y2_max) - max(y1_min, y2_min))
    # Calculate the union area
    union_area = (x1_max - x1_min) * (y1_max - y1_min) + (x2_max - x2_min) * (y2_max - y2_min) - inter_area

    return inter_area / union_area if union_area else 0

for gt_file in gt_files:
    base = os.path.basename(gt_file)
    pred_file = os.path.join(pred_dir, base)

    gt_labels = load_labels(gt_file)
    pred_labels = load_labels(pred_file) if os.path.exists(pred_file) else []

    for pred_label in pred_labels:
        pred_box = pred_label[2]  # This should be a list of bounding box coordinates
        score = pred_label[1]

        matched = False
        for gt_label in gt_labels:
            gt_box = gt_label[2]  # This should also be a list of bounding box coordinates

            if calculate_iou(gt_box, pred_box) >= 0.5:
                true_labels.append(1)  # True positive
                matched = True
                break

        if not matched:
            true_labels.append(0)  # False positive

        score_values.append(score)



# Calculate precision and recall for PR curve
precision, recall, thresholds = precision_recall_curve(true_labels, score_values)

plt.figure(figsize=(10, 6))
plt.plot(recall, precision, marker='.')
plt.title('Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %%
# Initialize variables for TP, FP, FN
tp, fp, fn = 0, 0, 0

for gt_file in gt_files:
    base = os.path.basename(gt_file)
    pred_file = os.path.join(pred_dir, base)

    gt_labels = load_labels(gt_file)
    pred_labels = load_labels(pred_file) if os.path.exists(pred_file) else []

    matched_gt = set()  # Track which ground truth labels are matched

    for pred_label in pred_labels:
        pred_box = pred_label[2]  # This should be a list of bounding box coordinates
        score = pred_label[1]

        matched = False
        for gt_label in gt_labels:
            gt_box = gt_label[2]  # This should also be a list of bounding box coordinates

            if calculate_iou(gt_box, pred_box) >= 0.5:
                tp += 1  # True positive
                # Convert bounding box coordinates in gt_label to tuple before adding
                matched_gt.add((gt_label[0], gt_label[1], tuple(gt_label[2])))
                matched = True
                break

        if not matched:
            fp += 1  # False positive

    # Calculate false negatives (missed ground truth)
    fn += len(gt_labels) - len(matched_gt)  # Subtract matched ground truths from total

# Calculate precision, recall, and F1 score
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print(f"Precision: {precision}, Recall: {recall}, F1 Score: {f1_score}")
# Out:
# Precision: 0.2585034013605442, Recall: 0.39790575916230364, F1 Score: 0.3134020618556701

# %% [markdown]
# IOU

# %%
# Initialize variables for TP, FP, FN
tp, fp, fn = 0, 0, 0

for gt_file in gt_files:
    base = os.path.basename(gt_file)
    pred_file = os.path.join(pred_dir, base)

    gt_labels = load_labels(gt_file)
    pred_labels = load_labels(pred_file) if os.path.exists(pred_file) else []

    matched_gt = set()  # Track which ground truth labels are matched

    for pred_label in pred_labels:
        pred_box = pred_label[2]  # This should be a list of bounding box coordinates
        score = pred_label[1]

        matched = False
        for gt_label in gt_labels:
            gt_box = gt_label[2]  # This should also be a list of bounding box coordinates

            if calculate_iou(gt_box, pred_box) >= 0.5:
                tp += 1  # True positive
                # Convert bounding box coordinates in gt_label to tuple before adding
                matched_gt.add((gt_label[0], gt_label[1], tuple(gt_label[2])))
                matched = True
                break

        if not matched:
            fp += 1  # False positive

    # Calculate false negatives (missed ground truth)
    fn += len(gt_labels) - len(matched_gt)  # Subtract matched ground truths from total

# Calculate precision, recall, and F1 score
precision = tp / (tp + fp) if (tp + fp) > 0 else 0
recall = tp / (tp + fn) if (tp + fn) > 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

print(f"Precision: {precision}, Recall: {recall}, F1 Score: {f1_score}")
# Out:
# Precision: 0.2585034013605442, Recall: 0.39790575916230364, F1 Score: 0.3134020618556701

# %%
# Calculate IoU values
ious = []
for gt_file in gt_files:
    base = os.path.basename(gt_file)
    pred_file = os.path.join(pred_dir, base)

    gt_labels = load_labels(gt_file)
    pred_labels = load_labels(pred_file) if os.path.exists(pred_file) else []

    for pred_label in pred_labels:
        pred_box = pred_label[2]  # This should be a list of bounding box coordinates

        for gt_label in gt_labels:
            gt_box = gt_label[2]  # This should also be a list of bounding box coordinates
            iou = calculate_iou(gt_box, pred_box)
            ious.append(iou)

# Plot IoU Distribution
plt.figure(figsize=(8, 6))
plt.hist(ious, bins=50, range=(0, 1), alpha=0.75)
plt.title('IoU Distribution')
plt.xlabel('IoU')
plt.ylabel('Frequency')
plt.show()
